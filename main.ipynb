# %%
from plotting_functions import *
import plotting_functions
import importlib
importlib.reload(plotting_functions)
from plotting_functions import *

# %%
basedata_path = "data/baseline_200_samples.csv"
basedata = load_data(datapath=basedata_path)

plot_grid(basedata, n=6, idx=3)

# %%
intD2_path = "data/intervention_100_D2.csv"
intD2_data = load_data(datapath=intD2_path)
plot_grid_hist(intD2_data, idx=3, n=6)

# %%
plot_pairwise_hist(basedata,intD2_data)

# %%
np.max(basedata[:,0] - basedata[:,3]**2)
# Out:
# np.float64(1.2407118689987564)

# %%
plt.scatter(basedata[:,3], basedata[:,0])
x = np.linspace(-10,3, 200)
y = x**2
plt.plot(x,y)

# %%
plt.scatter(basedata[:,1], basedata[:,0])
x = np.linspace(0,30, 200)
y = np.cos(x) + 4.2 +  basedata[:,3]**2
plt.plot(x,y)

# %%
plt.scatter(intD2_data[:,1], intD2_data[:,0])
x = np.linspace(0,30)
y = np.cos(x) + 4.2
plt.plot(x,y)

# %%
plt.hist(basedata[:,2], bins = 20)
plt.show()
plt.hist(intD2_data[:,2], bins = 20)
plt.show()

# %%
intFm2_path = "data/intervention_100_Fminus2.csv"
intFm2_data = load_data(datapath=intFm2_path)

plot_grid_hist(intFm2_data, n=6, idx=5)

# %%
plt.hist(intFm2_data[:,0], bins = 20)
plt.show()
plt.hist(basedata[:,0] * 1.6, bins = 20)
plt.show()
