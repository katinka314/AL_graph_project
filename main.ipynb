# %%
from plotting_functions import *

# %%
basedata_path = "data/baseline_200_samples.csv"

basedata = load_data(datapath=basedata_path)

plot_grid(basedata, n=6)

# %%
A = basedata[:,0]
B = basedata[:,1]
C = basedata[:,2]
D = basedata[:,3]
E = basedata[:,4]
F = basedata[:,5]
# Out:
# (200,)

# %%
basedata_mean = np.round(np.mean(basedata, axis=0), 2)
basedata_var = np.round(np.var(basedata, axis=0), 2)
basedata_std = np.round(np.std(basedata, axis=0), 2)

basedata_mean, basedata_var, basedata_std
# Out:
# (array([ 7.87,  4.6 , -0.01, -1.11, -1.21,  1.21]),
#  array([225.  ,  39.99,   2.69,   6.23,   0.87,   3.64]),
#  array([15.  ,  6.32,  1.64,  2.5 ,  0.93,  1.91]))
