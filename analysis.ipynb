# %%
import seaborn as sns
import pandas as pd

# %%
vars = ["A","B","C","D","E","F"]

# %% [markdown]
# # Baseline

# %%
data = pd.read_csv(r"data\baseline_200_samples.csv", usecols= vars)
data
# Out:
#              A         B         C         D         E         F
# 0     7.034942  1.087211  0.071169  2.515805 -2.405473  2.544125
# 1     4.874421  0.124294  3.475943  1.908251 -2.194978  5.580401
# 2    -0.041795  4.268048 -0.156468 -0.383868 -2.102513  2.272098
# 3     4.392423  9.171482  0.882335 -2.262698 -0.076396  0.775761
# 4    15.811783  2.950558 -0.130275 -4.068523 -1.940396  1.988671
# ..         ...       ...       ...       ...       ...       ...
# 195   5.954162  0.261246 -1.246915 -2.178848 -0.988815 -0.236519
# 196   0.978385  0.749201  0.149997 -0.073741 -0.570527  0.725176
# 197  -0.363205  3.093016 -0.842518 -0.628412 -1.556955  0.852012
# 198   3.627813  6.830127  3.487210  1.591534 -2.064623  5.523399
# 199   3.793586  0.353433 -0.152282 -1.616998 -1.238985  0.893087
#
# [200 rows x 6 columns]

# %%
sns.pairplot(data, diag_kind="hist")

# %%
sns.pairplot(data, kind="kde")

# %%
round(data.mean(axis=0),2), round(data.var(axis=0),2)
# Out:
# (A    7.87
#  B    4.60
#  C   -0.01
#  D   -1.11
#  E   -1.21
#  F    1.21
#  dtype: float64,
#  A    226.13
#  B     40.19
#  C      2.70
#  D      6.26
#  E      0.88
#  F      3.66
#  dtype: float64)

# %%
round(data.corr(),3)
# Out:
#        A      B      C      D      E      F
# A  1.000  0.026 -0.064 -0.796 -0.007 -0.050
# B  0.026  1.000  0.021 -0.057 -0.001  0.014
# C -0.064  0.021  1.000  0.059 -0.016  0.865
# D -0.796 -0.057  0.059  1.000 -0.239  0.161
# E -0.007 -0.001 -0.016 -0.239  1.000 -0.500
# F -0.050  0.014  0.865  0.161 -0.500  1.000
